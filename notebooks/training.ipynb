# %%
# !git clone https://github.com/haladaher2024/ML_project.git
# Out:
# Cloning into 'ML_project'...
# remote: Enumerating objects: 2690, done.
# remote: Counting objects: 100% (2690/2690), done.
# remote: Compressing objects: 100% (1843/1843), done.
# remote: Total 2690 (delta 21), reused 2647 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (2690/2690), 8.36 MiB | 17.19 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/training.ipynb" /content/ML_project/notebooks/training.ipynb
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab Notebooks/training.ipynb': No such file or directory
